# %% [markdown]
# #### <b>Download the pre-trained StyleGAN weights</b>

# %%
# !git clone https://github.com/ndb796/PyTorch-StyleGAN-Face-Editting
# %cd PyTorch-StyleGAN-Face-Editting
# !unzip weights/karras2019stylegan-ffhq-1024x1024.zip -d weights/
# Out:
# Cloning into 'PyTorch-StyleGAN-Face-Editting'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 112 (delta 24), reused 43 (delta 1), pack-reused 30
# Receiving objects: 100% (112/112), 95.16 MiB | 32.52 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/PyTorch-StyleGAN-Face-Editting
# Archive:  weights/karras2019stylegan-ffhq-1024x1024.zip
#   inflating: weights/karras2019stylegan-ffhq-1024x1024.pt

# %% [markdown]
# #### <b>Download celebrity face images</b>

# %%
# !git clone https://github.com/ndb796/StyleGAN-Embedding-PyTorch
# !cp -r StyleGAN-Embedding-PyTorch/celeba_hq_validation_100/ celeba_hq_validation_100/
# Out:
# Cloning into 'StyleGAN-Embedding-PyTorch'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (301/301), done.
# remote: Total 311 (delta 21), reused 274 (delta 6), pack-reused 0
# Receiving objects: 100% (311/311), 55.14 MiB | 30.26 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %% [markdown]
# #### <b>Load required libraries</b>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import models 
from torchvision import transforms
from torchvision.utils import save_image

from collections import OrderedDict
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time

# %% [markdown]
# #### <b>Load StyleGAN model</b>

# %%
from stylegan_model import G_mapping
from stylegan_model import G_synthesis

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
resolution = 1024
weight_file = 'weights/karras2019stylegan-ffhq-1024x1024.pt'

g_all = nn.Sequential(OrderedDict([
    ('g_mapping', G_mapping()),
    ('g_synthesis', G_synthesis(resolution=resolution))    
]))
g_all.load_state_dict(torch.load(weight_file, map_location=device))
g_all.eval()
g_all.to(device)

g_mapping, g_synthesis = g_all[0], g_all[1]

# %% [markdown]
# #### <b>Define utilities</b>

# %%
# Read an image from a file
def image_reader(image_path, resize=None):
    with open(image_path, "rb") as f:
        image = Image.open(f)
        image = image.convert("RGB")
    if resize != None:
        image = image.resize((resize, resize))
    transform = transforms.Compose([
        transforms.ToTensor() # [0, 1]
    ])
    image = transform(image)
    return image


# Show a torch image
def imshow(tensor):
    image = tensor.cpu().clone()
    image = image.squeeze(0)
    gray_scale = False
    if image.shape[0] == 1:
        gray_scale = True
    image = transforms.ToPILImage()(image)
    if gray_scale:
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(image)
    plt.show()


# Change the display resolution
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 80

# %% [markdown]
# #### <b>Embedding functions</b>

# %%
import warnings
warnings.filterwarnings(action='ignore')


# VGG feature extractor
class FeatureExtractor(torch.nn.Module):
    def __init__(self, n_layers):
        super(FeatureExtractor, self).__init__()
        self.mean = torch.tensor([0.485, 0.456, 0.406], device="cuda").view(-1, 1, 1)
        self.std = torch.tensor([0.229, 0.224, 0.225], device="cuda").view(-1, 1, 1)

        extractor = models.vgg16(pretrained=True).features

        index = 0
        self.layers = nn.ModuleList([])
        for i in range(len(n_layers)):
            self.layers.append(torch.nn.Sequential())
            for j in range(index, n_layers[i] + 1):
                self.layers[i].add_module(str(j), extractor[j])
            index = n_layers[i] + 1

        for param in self.parameters():
            param.requires_grad = False

    def forward(self, x):
        x = (x - self.mean) / self.std

        result = []
        for i in range(len(self.layers)):
            x = self.layers[i](x)
            result.append(x)

        return result

# %%
def loss_function(generated_image, target_image, feature_extractor):
    MSE = nn.MSELoss(reduction='mean')
    mse_loss = MSE(generated_image, target_image)

    upsample2d = torch.nn.Upsample(scale_factor=256 / resolution, mode='bilinear')
    real_features = feature_extractor(upsample2d(target_image))
    generated_features = feature_extractor(upsample2d(generated_image))

    perceptual_loss = 0
    for i in range(len(real_features)):
        perceptual_loss += MSE(real_features[i], generated_features[i])

    return mse_loss, perceptual_loss

# %% [markdown]
# #### <b>Read all images</b>

# %%
import os
import torch.utils.data as data


class CustomDataset(data.Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.images = os.listdir(root_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = os.path.join(self.root_dir, self.images[idx])
        image_name = self.images[idx].split('.')[0]
        return image_reader(image_path), image_name


male_dataset = CustomDataset('./celeba_hq_validation_100/male')
male_train_dataloader = data.DataLoader(male_dataset , batch_size=8, shuffle=False, num_workers=4)

# %% [markdown]
# #### <b>Embedding experiments</b>

# %%
# !mkdir -p ./outputs/male

# %%
start_time = time.time()
save_path = './outputs/male/'

for step, (images, names) in enumerate(male_train_dataloader):
    images = images.to(device)

    latents = torch.zeros((images.shape[0], 18, 512), requires_grad=True, device=device) # latent vector
    optimizer_latent = optim.Adam({latents}, lr=0.01, betas=(0.9, 0.999), eps=1e-8)

    # VGG perceptual loss
    feature_extractor = FeatureExtractor(n_layers=[7, 14]).to(device)

    # Start the optimization
    iteration = 1000
    for i in range(iteration):
        optimizer_latent.zero_grad()

        # generate an image from a latent vector
        generated_images = g_synthesis(latents)
        generated_images = (generated_images + 1.0) / 2.0
        generated_images = generated_images.clamp(0, 1)

        loss = 0
        mse_loss, perceptual_loss = loss_function(generated_images, images, feature_extractor)
        loss += mse_loss + perceptual_loss
        loss.backward() # calculate the gradient

        optimizer_latent.step() # update the latent vector

        if i == 0 or (i + 1) % 100 == 0:
            print(f'[iter {i + 1}/{iteration}] loss = {loss.detach().cpu().numpy()} time = {time.time() - start_time}')
            for j in range(images.shape[0]):
                save_image(generated_images[j], save_path + f'{names[j]}_iter_{i + 1}.png')
                np.save(save_path + f'{names[j]}_latent.npy', latents[j].detach().cpu().numpy())

    print(f"[ Step #{step + 1} Embedding Complete ]")
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# [iter 1/1000] loss = 137.1265869140625 time = 7.251039028167725
# [iter 100/1000] loss = 55.309814453125 time = 120.58369493484497
# [iter 200/1000] loss = 48.14405059814453 time = 237.74634861946106
# [iter 300/1000] loss = 42.90700149536133 time = 355.0690541267395
# [iter 400/1000] loss = 40.24180221557617 time = 472.37676906585693
# [iter 500/1000] loss = 37.87495040893555 time = 589.8395824432373
# [iter 600/1000] loss = 35.82023239135742 time = 707.140885591507
# [iter 700/1000] loss = 34.61066436767578 time = 824.5731105804443
# [iter 800/1000] loss = 33.59798049926758 time = 941.9210629463196
# [iter 900/1000] loss = 32.47978973388672 time = 1059.2638478279114
# [iter 1000/1000] loss = 31.62347412109375 time = 1176.691154718399
# [ Step #1 Embedding Complete ]
# %%
print('[ Face Interpolation ]')

# load w vectors from .npy files
w_1 = np.load('./outputs/male/007143_latent.npy')
w_2 = np.load('./outputs/male/006877_latent.npy')

name = 'interpolation'
interpolated_images = []

# face morphing
with torch.no_grad():
    for alpha in np.linspace(0, 1, 10):
        w = (1 - alpha) * w_1 + alpha * w_2
        w = torch.tensor(w).to(device)
        image = g_synthesis(w.unsqueeze(0))
        image = ((image + 1.0) / 2.0).clamp(0, 1)
        interpolated_images.append(image)

# save the result image
grid_image = torchvision.utils.make_grid(torch.cat(interpolated_images, dim=0), nrow=5)
save_image(grid_image, f"{name}.png")
imshow(grid_image)
# Out:
# [ Face Interpolation ]

# %%
# !zip -r compressed.zip ./outputs/male/*_latent.npy
# Out:
#   adding: outputs/male/000080_latent.npy (deflated 7%)
#   adding: outputs/male/000143_latent.npy (deflated 7%)
#   adding: outputs/male/000196_latent.npy (deflated 7%)
#   adding: outputs/male/000406_latent.npy (deflated 7%)
#   adding: outputs/male/000443_latent.npy (deflated 7%)
#   adding: outputs/male/000534_latent.npy (deflated 7%)
#   adding: outputs/male/000622_latent.npy (deflated 7%)
#   adding: outputs/male/000801_latent.npy (deflated 7%)
#   adding: outputs/male/000990_latent.npy (deflated 7%)
#   adding: outputs/male/001022_latent.npy (deflated 7%)
#   adding: outputs/male/001036_latent.npy (deflated 7%)
#   adding: outputs/male/001074_latent.npy (deflated 7%)
#   adding: outputs/male/001092_latent.npy (deflated 7%)
#   adding: outputs/male/001693_latent.npy (deflated 7%)
#   adding: outputs/male/001804_latent.npy (deflated 7%)
#   adding: outputs/male/002123_latent.npy (deflated 7%)
#   adding: outputs/male/002317_latent.npy (deflated 7%)
#   adding: outputs/male/002378_latent.npy (deflated 7%)
#   adding: outputs/male/002528_latent.npy (deflated 7%)
#   adding: outputs/male/002708_latent.npy (deflated 7%)
#   adding: outputs/male/002768_latent.npy (deflated 7%)
#   adding: outputs/male/002963_latent.npy (deflated 7%)
#   adding: outputs/male/003309_latent.npy (deflated 7%)
#   adding: outputs/male/003569_latent.npy (deflated 7%)
#   adding: outputs/male/003622_latent.npy (deflated 7%)
#   adding: outputs/male/003959_latent.npy (deflated 7%)
#   adding: outputs/male/004056_latent.npy (deflated 7%)
#   adding: outputs/male/004666_latent.npy (deflated 7%)
#   adding: outputs/male/005235_latent.npy (deflated 7%)
#   adding: outputs/male/005387_latent.npy (deflated 7%)
#   adding: outputs/male/005503_latent.npy (deflated 7%)
#   adding: outputs/male/005539_latent.npy (deflated 7%)
#   adding: outputs/male/005735_latent.npy (deflated 7%)
#   adding: outputs/male/005799_latent.npy (deflated 7%)
#   adding: outputs/male/005846_latent.npy (deflated 7%)
#   adding: outputs/male/005926_latent.npy (deflated 7%)
#   adding: outputs/male/006085_latent.npy (deflated 7%)
#   adding: outputs/male/006087_latent.npy (deflated 7%)
#   adding: outputs/male/006595_latent.npy (deflated 7%)
#   adding: outputs/male/006636_latent.npy (deflated 7%)
#   adding: outputs/male/006750_latent.npy (deflated 7%)
#   adding: outputs/male/006877_latent.npy (deflated 7%)
#   adding: outputs/male/006930_latent.npy (deflated 7%)
#   adding: outputs/male/007143_latent.npy (deflated 7%)
#   adding: outputs/male/007536_latent.npy (deflated 7%)
#   adding: outputs/male/007821_latent.npy (deflated 7%)
#   adding: outputs/male/008149_latent.npy (deflated 7%)
#   adding: outputs/male/008548_latent.npy (deflated 7%)
#   adding: outputs/male/008550_latent.npy (deflated 7%)
#   adding: outputs/male/008582_latent.npy (deflated 7%)
#   adding: outputs/male/008843_latent.npy (deflated 7%)
#   adding: outputs/male/008966_latent.npy (deflated 7%)
#   adding: outputs/male/008994_latent.npy (deflated 7%)
#   adding: outputs/male/009250_latent.npy (deflated 7%)
#   adding: outputs/male/009556_latent.npy (deflated 7%)
#   adding: outputs/male/009742_latent.npy (deflated 7%)
#   adding: outputs/male/009858_latent.npy (deflated 7%)
#   adding: outputs/male/010151_latent.npy (deflated 7%)
#   adding: outputs/male/010168_latent.npy (deflated 7%)
#   adding: outputs/male/010169_latent.npy (deflated 7%)
#   adding: outputs/male/010264_latent.npy (deflated 7%)
#   adding: outputs/male/010309_latent.npy (deflated 7%)
#   adding: outputs/male/010441_latent.npy (deflated 7%)
#   adding: outputs/male/010492_latent.npy (deflated 7%)
#   adding: outputs/male/010791_latent.npy (deflated 7%)
#   adding: outputs/male/011050_latent.npy (deflated 7%)
#   adding: outputs/male/011467_latent.npy (deflated 7%)
#   adding: outputs/male/011472_latent.npy (deflated 7%)
#   adding: outputs/male/011629_latent.npy (deflated 7%)
#   adding: outputs/male/011696_latent.npy (deflated 7%)
#   adding: outputs/male/011968_latent.npy (deflated 7%)
#   adding: outputs/male/012148_latent.npy (deflated 7%)
#   adding: outputs/male/012279_latent.npy (deflated 7%)
#   adding: outputs/male/012424_latent.npy (deflated 7%)
#   adding: outputs/male/012595_latent.npy (deflated 7%)
#   adding: outputs/male/012712_latent.npy (deflated 7%)
#   adding: outputs/male/012734_latent.npy (deflated 7%)
#   adding: outputs/male/012778_latent.npy (deflated 7%)
#   adding: outputs/male/013333_latent.npy (deflated 7%)
#   adding: outputs/male/013340_latent.npy (deflated 7%)
#   adding: outputs/male/013706_latent.npy (deflated 7%)
#   adding: outputs/male/013796_latent.npy (deflated 7%)
#   adding: outputs/male/013881_latent.npy (deflated 7%)
#   adding: outputs/male/014314_latent.npy (deflated 7%)
#   adding: outputs/male/014891_latent.npy (deflated 7%)
#   adding: outputs/male/014895_latent.npy (deflated 7%)
#   adding: outputs/male/014977_latent.npy (deflated 7%)
#   adding: outputs/male/015088_latent.npy (deflated 7%)
#   adding: outputs/male/015552_latent.npy (deflated 7%)
#   adding: outputs/male/015604_latent.npy (deflated 7%)
#   adding: outputs/male/015620_latent.npy (deflated 7%)
#   adding: outputs/male/015913_latent.npy (deflated 7%)
#   adding: outputs/male/015940_latent.npy (deflated 7%)
#   adding: outputs/male/016191_latent.npy (deflated 7%)
#   adding: outputs/male/019706_latent.npy (deflated 7%)
#   adding: outputs/male/043712_latent.npy (deflated 7%)
#   adding: outputs/male/064978_latent.npy (deflated 7%)
#   adding: outputs/male/078959_latent.npy (deflated 7%)
#   adding: outputs/male/140022_latent.npy (deflated 7%)
#   adding: outputs/male/141122_latent.npy (deflated 7%)
