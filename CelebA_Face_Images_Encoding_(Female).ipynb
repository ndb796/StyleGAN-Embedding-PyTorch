# %% [markdown]
# #### <b>Download the pre-trained StyleGAN weights</b>

# %%
# !git clone https://github.com/ndb796/PyTorch-StyleGAN-Face-Editting
# %cd PyTorch-StyleGAN-Face-Editting
# !unzip weights/karras2019stylegan-ffhq-1024x1024.zip -d weights/
# Out:
# Cloning into 'PyTorch-StyleGAN-Face-Editting'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 112 (delta 24), reused 43 (delta 1), pack-reused 30
# Receiving objects: 100% (112/112), 95.16 MiB | 34.32 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /content/PyTorch-StyleGAN-Face-Editting
# Archive:  weights/karras2019stylegan-ffhq-1024x1024.zip
#   inflating: weights/karras2019stylegan-ffhq-1024x1024.pt

# %% [markdown]
# #### <b>Download celebrity face images</b>

# %%
# !git clone https://github.com/ndb796/StyleGAN-Embedding-PyTorch
# !cp -r StyleGAN-Embedding-PyTorch/celeba_hq_validation_100/ celeba_hq_validation_100/
# Out:
# Cloning into 'StyleGAN-Embedding-PyTorch'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (301/301), done.
# remote: Total 311 (delta 21), reused 274 (delta 6), pack-reused 0
# Receiving objects: 100% (311/311), 55.14 MiB | 26.15 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %% [markdown]
# #### <b>Load required libraries</b>

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import models 
from torchvision import transforms
from torchvision.utils import save_image

from collections import OrderedDict
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time

# %% [markdown]
# #### <b>Load StyleGAN model</b>

# %%
from stylegan_model import G_mapping
from stylegan_model import G_synthesis

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
resolution = 1024
weight_file = 'weights/karras2019stylegan-ffhq-1024x1024.pt'

g_all = nn.Sequential(OrderedDict([
    ('g_mapping', G_mapping()),
    ('g_synthesis', G_synthesis(resolution=resolution))    
]))
g_all.load_state_dict(torch.load(weight_file, map_location=device))
g_all.eval()
g_all.to(device)

g_mapping, g_synthesis = g_all[0], g_all[1]

# %% [markdown]
# #### <b>Define utilities</b>

# %%
# Read an image from a file
def image_reader(image_path, resize=None):
    with open(image_path, "rb") as f:
        image = Image.open(f)
        image = image.convert("RGB")
    if resize != None:
        image = image.resize((resize, resize))
    transform = transforms.Compose([
        transforms.ToTensor() # [0, 1]
    ])
    image = transform(image)
    return image


# Show a torch image
def imshow(tensor):
    image = tensor.cpu().clone()
    image = image.squeeze(0)
    gray_scale = False
    if image.shape[0] == 1:
        gray_scale = True
    image = transforms.ToPILImage()(image)
    if gray_scale:
        plt.imshow(image, cmap='gray')
    else:
        plt.imshow(image)
    plt.show()


# Change the display resolution
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 80

# %% [markdown]
# #### <b>Embedding functions</b>

# %%
import warnings
warnings.filterwarnings(action='ignore')


# VGG feature extractor
class FeatureExtractor(torch.nn.Module):
    def __init__(self, n_layers):
        super(FeatureExtractor, self).__init__()
        self.mean = torch.tensor([0.485, 0.456, 0.406], device="cuda").view(-1, 1, 1)
        self.std = torch.tensor([0.229, 0.224, 0.225], device="cuda").view(-1, 1, 1)

        extractor = models.vgg16(pretrained=True).features

        index = 0
        self.layers = nn.ModuleList([])
        for i in range(len(n_layers)):
            self.layers.append(torch.nn.Sequential())
            for j in range(index, n_layers[i] + 1):
                self.layers[i].add_module(str(j), extractor[j])
            index = n_layers[i] + 1

        for param in self.parameters():
            param.requires_grad = False

    def forward(self, x):
        x = (x - self.mean) / self.std

        result = []
        for i in range(len(self.layers)):
            x = self.layers[i](x)
            result.append(x)

        return result

# %%
def loss_function(generated_image, target_image, feature_extractor):
    MSE = nn.MSELoss(reduction='mean')
    mse_loss = MSE(generated_image, target_image)

    upsample2d = torch.nn.Upsample(scale_factor=256 / resolution, mode='bilinear')
    real_features = feature_extractor(upsample2d(target_image))
    generated_features = feature_extractor(upsample2d(generated_image))

    perceptual_loss = 0
    for i in range(len(real_features)):
        perceptual_loss += MSE(real_features[i], generated_features[i])

    return mse_loss, perceptual_loss

# %% [markdown]
# #### <b>Read all images</b>

# %%
import os
import torch.utils.data as data


class CustomDataset(data.Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        self.images = os.listdir(root_dir)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = os.path.join(self.root_dir, self.images[idx])
        image_name = self.images[idx].split('.')[0]
        return image_reader(image_path), image_name


female_dataset = CustomDataset('./celeba_hq_validation_100/female')
female_train_dataloader = data.DataLoader(female_dataset , batch_size=8, shuffle=False, num_workers=4)

# %% [markdown]
# #### <b>Embedding experiments</b>

# %%
# !mkdir -p ./outputs/female

# %%
start_time = time.time()
save_path = './outputs/female/'

for step, (images, names) in enumerate(female_train_dataloader):
    images = images.to(device)

    latents = torch.zeros((images.shape[0], 18, 512), requires_grad=True, device=device) # latent vector
    optimizer_latent = optim.Adam({latents}, lr=0.01, betas=(0.9, 0.999), eps=1e-8)

    # VGG perceptual loss
    feature_extractor = FeatureExtractor(n_layers=[7, 14]).to(device)

    # Start the optimization
    iteration = 1000
    for i in range(iteration):
        optimizer_latent.zero_grad()

        # generate an image from a latent vector
        generated_images = g_synthesis(latents)
        generated_images = (generated_images + 1.0) / 2.0
        generated_images = generated_images.clamp(0, 1)

        loss = 0
        mse_loss, perceptual_loss = loss_function(generated_images, images, feature_extractor)
        loss += mse_loss + perceptual_loss
        loss.backward() # calculate the gradient

        optimizer_latent.step() # update the latent vector

        if i == 0 or (i + 1) % 100 == 0:
            print(f'[iter {i + 1}/{iteration}] loss = {loss.detach().cpu().numpy()} time = {time.time() - start_time}')
            for j in range(images.shape[0]):
                save_image(generated_images[j], save_path + f'{names[j]}_iter_{i + 1}.png')
                np.save(save_path + f'{names[j]}_latent.npy', latents[j].detach().cpu().numpy())

    print(f"[ Step #{step + 1} Embedding Complete ]")
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# [iter 1/1000] loss = 127.47525024414062 time = 6.922518730163574
# [iter 100/1000] loss = 46.46649932861328 time = 117.57054448127747
# [iter 200/1000] loss = 39.56591796875 time = 231.00260663032532
# [iter 300/1000] loss = 35.85902404785156 time = 344.8699791431427
# [iter 400/1000] loss = 33.45124053955078 time = 458.790100812912
# [iter 500/1000] loss = 32.72623062133789 time = 572.6718471050262
# [iter 600/1000] loss = 32.50486755371094 time = 686.6045341491699
# [iter 700/1000] loss = 29.682296752929688 time = 800.4611387252808
# [iter 800/1000] loss = 28.77488136291504 time = 914.3665196895599
# [iter 900/1000] loss = 27.771875381469727 time = 1028.2310252189636
# [iter 1000/1000] loss = 27.326641082763672 time = 1142.0796327590942
# [ Step #1 Embedding Complete ]
# [iter 1/1000] loss = 140.64219665527344 time = 1149.3666491508484
# [iter 100/1000] loss = 64.10774993896484 time = 1261.7833728790283
name = 'interpolation'
interpolated_images = []

# face morphing
with torch.no_grad():
    for alpha in np.linspace(0, 1, 10):
        w = (1 - alpha) * w_1 + alpha * w_2
        w = torch.tensor(w).to(device)
        image = g_synthesis(w.unsqueeze(0))
        image = ((image + 1.0) / 2.0).clamp(0, 1)
        interpolated_images.append(image)

# save the result image
grid_image = torchvision.utils.make_grid(torch.cat(interpolated_images, dim=0), nrow=5)
save_image(grid_image, f"{name}.png")
imshow(grid_image)
# Out:
# [ Face Interpolation ]

# %%
# !zip -r compressed.zip ./outputs/female/*_latent.npy
# Out:
#   adding: outputs/female/000431_latent.npy (deflated 7%)
#   adding: outputs/female/000442_latent.npy (deflated 7%)
#   adding: outputs/female/000446_latent.npy (deflated 7%)
#   adding: outputs/female/000528_latent.npy (deflated 7%)
#   adding: outputs/female/000656_latent.npy (deflated 7%)
#   adding: outputs/female/001349_latent.npy (deflated 7%)
#   adding: outputs/female/001496_latent.npy (deflated 7%)
#   adding: outputs/female/001663_latent.npy (deflated 7%)
#   adding: outputs/female/001743_latent.npy (deflated 7%)
#   adding: outputs/female/001972_latent.npy (deflated 7%)
#   adding: outputs/female/002064_latent.npy (deflated 7%)
#   adding: outputs/female/002140_latent.npy (deflated 7%)
#   adding: outputs/female/002292_latent.npy (deflated 7%)
#   adding: outputs/female/002419_latent.npy (deflated 7%)
#   adding: outputs/female/002420_latent.npy (deflated 7%)
#   adding: outputs/female/002475_latent.npy (deflated 7%)
#   adding: outputs/female/002569_latent.npy (deflated 7%)
#   adding: outputs/female/003247_latent.npy (deflated 7%)
#   adding: outputs/female/003251_latent.npy (deflated 7%)
#   adding: outputs/female/003536_latent.npy (deflated 7%)
#   adding: outputs/female/003716_latent.npy (deflated 7%)
#   adding: outputs/female/003767_latent.npy (deflated 7%)
#   adding: outputs/female/003789_latent.npy (deflated 7%)
#   adding: outputs/female/004070_latent.npy (deflated 7%)
#   adding: outputs/female/004253_latent.npy (deflated 7%)
#   adding: outputs/female/004480_latent.npy (deflated 7%)
#   adding: outputs/female/004487_latent.npy (deflated 7%)
#   adding: outputs/female/004526_latent.npy (deflated 7%)
#   adding: outputs/female/004603_latent.npy (deflated 7%)
#   adding: outputs/female/004715_latent.npy (deflated 7%)
#   adding: outputs/female/004730_latent.npy (deflated 7%)
#   adding: outputs/female/004763_latent.npy (deflated 7%)
#   adding: outputs/female/004858_latent.npy (deflated 7%)
#   adding: outputs/female/004892_latent.npy (deflated 7%)
#   adding: outputs/female/004911_latent.npy (deflated 7%)
#   adding: outputs/female/005061_latent.npy (deflated 7%)
#   adding: outputs/female/005134_latent.npy (deflated 7%)
#   adding: outputs/female/005586_latent.npy (deflated 7%)
#   adding: outputs/female/005664_latent.npy (deflated 7%)
#   adding: outputs/female/005670_latent.npy (deflated 7%)
#   adding: outputs/female/005703_latent.npy (deflated 7%)
#   adding: outputs/female/005923_latent.npy (deflated 7%)
#   adding: outputs/female/006012_latent.npy (deflated 7%)
#   adding: outputs/female/006105_latent.npy (deflated 7%)
#   adding: outputs/female/006720_latent.npy (deflated 7%)
#   adding: outputs/female/006878_latent.npy (deflated 7%)
#   adding: outputs/female/007072_latent.npy (deflated 7%)
#   adding: outputs/female/007075_latent.npy (deflated 7%)
#   adding: outputs/female/007150_latent.npy (deflated 7%)
#   adding: outputs/female/007156_latent.npy (deflated 7%)
#   adding: outputs/female/007224_latent.npy (deflated 7%)
#   adding: outputs/female/007250_latent.npy (deflated 7%)
#   adding: outputs/female/007398_latent.npy (deflated 7%)
#   adding: outputs/female/007425_latent.npy (deflated 7%)
#   adding: outputs/female/007710_latent.npy (deflated 7%)
#   adding: outputs/female/007798_latent.npy (deflated 7%)
#   adding: outputs/female/007810_latent.npy (deflated 7%)
#   adding: outputs/female/007817_latent.npy (deflated 7%)
#   adding: outputs/female/008113_latent.npy (deflated 7%)
#   adding: outputs/female/008210_latent.npy (deflated 7%)
#   adding: outputs/female/008322_latent.npy (deflated 7%)
#   adding: outputs/female/008472_latent.npy (deflated 7%)
#   adding: outputs/female/008604_latent.npy (deflated 7%)
#   adding: outputs/female/008731_latent.npy (deflated 7%)
#   adding: outputs/female/009120_latent.npy (deflated 7%)
#   adding: outputs/female/009661_latent.npy (deflated 7%)
#   adding: outputs/female/009698_latent.npy (deflated 7%)
#   adding: outputs/female/009737_latent.npy (deflated 7%)
#   adding: outputs/female/009882_latent.npy (deflated 7%)
#   adding: outputs/female/010011_latent.npy (deflated 7%)
#   adding: outputs/female/010092_latent.npy (deflated 7%)
#   adding: outputs/female/010239_latent.npy (deflated 7%)
#   adding: outputs/female/010551_latent.npy (deflated 7%)
#   adding: outputs/female/010588_latent.npy (deflated 7%)
#   adding: outputs/female/010839_latent.npy (deflated 7%)
#   adding: outputs/female/010866_latent.npy (deflated 7%)
#   adding: outputs/female/010961_latent.npy (deflated 7%)
#   adding: outputs/female/011055_latent.npy (deflated 7%)
#   adding: outputs/female/011185_latent.npy (deflated 7%)
#   adding: outputs/female/012198_latent.npy (deflated 7%)
#   adding: outputs/female/012588_latent.npy (deflated 7%)
#   adding: outputs/female/012608_latent.npy (deflated 7%)
#   adding: outputs/female/012616_latent.npy (deflated 7%)
#   adding: outputs/female/012675_latent.npy (deflated 7%)
#   adding: outputs/female/012931_latent.npy (deflated 7%)
#   adding: outputs/female/013461_latent.npy (deflated 7%)
#   adding: outputs/female/013591_latent.npy (deflated 7%)
#   adding: outputs/female/013624_latent.npy (deflated 7%)
#   adding: outputs/female/013727_latent.npy (deflated 7%)
#   adding: outputs/female/013782_latent.npy (deflated 7%)
#   adding: outputs/female/013902_latent.npy (deflated 7%)
#   adding: outputs/female/013980_latent.npy (deflated 7%)
#   adding: outputs/female/014015_latent.npy (deflated 7%)
#   adding: outputs/female/014062_latent.npy (deflated 7%)
#   adding: outputs/female/014538_latent.npy (deflated 7%)
#   adding: outputs/female/052085_latent.npy (deflated 7%)
#   adding: outputs/female/052599_latent.npy (deflated 7%)
#   adding: outputs/female/052936_latent.npy (deflated 7%)
#   adding: outputs/female/053372_latent.npy (deflated 7%)
#   adding: outputs/female/053405_latent.npy (deflated 7%)
